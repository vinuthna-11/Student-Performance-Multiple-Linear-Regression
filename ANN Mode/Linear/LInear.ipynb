# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('../Student_Performance.csv')
df.head()
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
#
#    Sample Question Papers Practiced
# 0                                 1

# %% [markdown]
# ## Visualization of In-dependent with dependent variable

# %%
for var in X.columns.tolist():
    plt.figure(figsize=(8, 6))
    if X[var].dtype == 'object':  # Check if the variable is categorical
        sns.scatterplot(x=var, y=Y, data=df, hue=var)
    else:
        sns.scatterplot(x=X[var], y=Y)
    plt.title(f'Scatter Plot of {var} vs Charges')
    plt.xlabel(var)
    plt.ylabel('Charges')
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
X.iloc[:, 2] = label_encoder.fit_transform(X.iloc[:, 2])
print(type(X))
X
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                          0            9
#
#    Sample Question Papers Practiced
# 0                                 1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
#
# File ~/ai project/venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/ai project/venv/lib/python3.13/site-packages/sklearn/model_selection/_split.py:2919, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2916 arrays = indexable(*arrays)
#    2918 n_samples = _num_samples(arrays[0])
# -> 2919 n_train, n_test = _validate_shuffle_split(
#    2920     n_samples, test_size, train_size, default_test_size=0.25
#    2921 )
#    2923 if shuffle is False:
#    2924     if stratify is not None:
#
# File ~/ai project/venv/lib/python3.13/site-packages/sklearn/model_selection/_split.py:2499, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2496 n_train, n_test = int(n_train), int(n_test)
#    2498 if n_train == 0:
# -> 2499     raise ValueError(
#    2500         "With n_samples={}, test_size={} and train_size={}, the "
#    2501         "resulting train set will be empty. Adjust any of the "
#    2502         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2503     )
#    2505 return n_train, n_test
#
# ValueError: With n_samples=1, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from sklearn.linear_model import LinearRegression
regresor=LinearRegression()
regresor.fit(X_train,Y_train)
Y_pred=regresor.predict(X_test)

# %%
print(Y_test.shape, Y_pred.shape)
# Out:
# (2000,) (2000,)

# %% [markdown]
# # Accuracy Check

# %%
from sklearn.metrics import r2_score
r2=r2_score(Y_test,Y_pred)
print(r2)
# Out:
# 0.9880686410711422
